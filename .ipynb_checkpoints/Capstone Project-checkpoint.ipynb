# %%
import pandas as pd
import seaborn as sns
import numpy as np
sns.set()
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
raw_poverty_df = pd.read_csv('poverty_statistics.csv')

raw_voter_df = pd.read_csv('voter_turnout.csv')

raw_presidential_vs_midterm_df = pd.read_csv('presidential_vs_midterm.csv')

raw_extra_poverty_statistics_df = pd.read_csv('extra_poverty_statistics.csv')

raw_welfare_df = pd.read_csv('welfare_stats.csv')

raw_gdp_df = pd.read_csv('gdp_per_capita.csv')

# %%
raw_gdp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year                 30 non-null     int64
#  1   Real GDP Per Capita  30 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 608.0+ bytes

# %%
raw_extra_poverty_statistics_df.head()
# Out:
#    Years          18 to 64 years (%)          65+ years (%)  \
# 0   1980                       0.101                  0.157
# 1   1982                       0.120                  0.146
# 2   1984                       0.117                  0.124
# 3   1986                       0.108                  0.124
# 4   1988                       0.105                  0.120
#
#            Married couple families without children (%)  \
# 0                                              0.045
# 1                                              0.054
# 2                                              0.045
# 3                                              0.041
# 4                                              0.040
#
#            Married couple families with children (%)  \
# 0                                              0.077
# 1                                              0.098
# 2                                              0.094
# 3                                              0.080
# 4                                              0.072
#
#            Persons not in families/Unrelated individuals (%)  \
# 0                                              0.086
# 1                                              0.115
# 2                                              0.106
# 3                                              0.092
# 4                                              0.089
#
#            Male householder, no spouse present with children (%)  \
# 0                                              0.180
# 1                                              0.206
# 2                                              0.181
# 3                                              0.178
# 4                                              0.180
#
#            Female householder, no spouse present with children (%)  \
# 0                                              0.429
# 1                                              0.478
# 2                                              0.457
# 3                                              0.460
# 4                                              0.447
#
#            White (%)          Black (%)  ...          South Dakota (%)  \
# 0              0.102              0.325  ...                     0.188
# 1              0.120              0.356  ...                     0.168
# 2              0.115              0.338  ...                     0.145
# 3              0.110              0.311  ...                     0.170
# 4              0.101              0.313  ...                     0.142
#
#            Tennessee (%)          Texas (%)          Utah (%)  \
# 0                  0.196              0.157             0.100
# 1                  0.236              0.162             0.145
# 2                  0.174              0.157             0.111
# 3                  0.183              0.173             0.126
# 4                  0.180              0.180             0.098
#
#            Vermont (%)          Virginia (%)          Washington (%)  \
# 0                0.120                 0.124                   0.127
# 1                0.129                 0.125                   0.129
# 2                0.126                 0.100                   0.113
# 3                0.110                 0.097                   0.129
# 4                0.081                 0.108                   0.087
#
#            West Virginia (%)          Wisconsin (%)          Wyoming (%)
# 0                      0.152                  0.085                0.104
# 1                      0.248                  0.095                0.120
# 2                      0.204                  0.155                0.109
# 3                      0.224                  0.107                0.146
# 4                      0.179                  0.078                0.096
#
# [5 rows x 67 columns]

# %%
raw_extra_poverty_statistics_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 67 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   Years                                                            20 non-null     int64
#  1           18 to 64 years (%)                                       20 non-null     float64
#  2           65+ years (%)                                            20 non-null     float64
#  3           Married couple families without children (%)             20 non-null     float64
#  4           Married couple families with children (%)                20 non-null     float64
#  5           Persons not in families/Unrelated individuals (%)        20 non-null     float64
#  6           Male householder, no spouse present with children (%)    20 non-null     float64
#  7           Female householder, no spouse present with children (%)  20 non-null     float64
#  8           White (%)                                                20 non-null     float64
#  9           Black (%)                                                20 non-null     float64
#  10          Hispanic (%)                                             20 non-null     float64
#  11          White, non-Hispanic (%)                                  20 non-null     float64
#  12          Northeast (%)                                            20 non-null     float64
#  13          West (%)                                                 20 non-null     float64
#  14          South (%)                                                20 non-null     float64
#  15          Midwest (%)                                              20 non-null     float64
#  16          Alabama (%)                                              20 non-null     float64
#  17          Alaska (%)                                               20 non-null     float64
#  18          Arizona (%)                                              20 non-null     float64
#  19          Arkansas (%)                                             20 non-null     float64
#  20          California (%)                                           20 non-null     float64
#  21          Colorado (%)                                             20 non-null     float64
#  22          Connecticut (%)                                          20 non-null     float64
#  23          Delaware (%)                                             20 non-null     float64
#  24          District of Columbia (%)                                 20 non-null     float64
#  25          Florida (%)                                              20 non-null     float64
#  26          Georgia (%)                                              20 non-null     float64
#  27          Hawaii (%)                                               20 non-null     float64
#  28          Idaho (%)                                                20 non-null     float64
#  29          Illinois (%)                                             20 non-null     float64
#  30          Indiana (%)                                              20 non-null     float64
#  31          Iowa (%)                                                 20 non-null     float64
#  32          Kansas (%)                                               20 non-null     float64
#  33          Kentucky (%)                                             20 non-null     float64
#  34          Louisiana (%)                                            20 non-null     float64
#  35          Maine (%)                                                20 non-null     float64
#  36          Maryland (%)                                             20 non-null     float64
#  37          Massachusetts (%)                                        20 non-null     float64
#  38          Michigan (%)                                             20 non-null     float64
#  39          Minnesota (%)                                            20 non-null     float64
#  40          Mississippi (%)                                          20 non-null     float64
#  41          Missouri (%)                                             20 non-null     float64
#  42          Montana (%)                                              20 non-null     float64
#  43          Nebraska (%)                                             20 non-null     float64
#  44          Nevada (%)                                               20 non-null     float64
#  45          New Hampshire (%)                                        20 non-null     float64
#  46          New Jersey (%)                                           20 non-null     float64
#  47          New Mexico (%)                                           20 non-null     float64
#  48          New York (%)                                             20 non-null     float64
#  49          North Carolina (%)                                       20 non-null     float64
#  50          North Dakota (%)                                         20 non-null     float64
#  51          Ohio (%)                                                 20 non-null     float64
#  52          Oklahoma (%)                                             20 non-null     float64
#  53          Oregon (%)                                               20 non-null     float64
#  54          Pennsylvania (%)                                         20 non-null     float64
#  55          Rhode Island (%)                                         20 non-null     float64
#  56          South Carolina (%)                                       20 non-null     float64
#  57          South Dakota (%)                                         20 non-null     float64
#  58          Tennessee (%)                                            20 non-null     float64
#  59          Texas (%)                                                20 non-null     float64
#  60          Utah (%)                                                 20 non-null     float64
#  61          Vermont (%)                                              20 non-null     float64
#  62          Virginia (%)                                             20 non-null     float64
#  63          Washington (%)                                           20 non-null     float64
#  64          West Virginia (%)                                        20 non-null     float64
#  65          Wisconsin (%)                                            20 non-null     float64
#  66          Wyoming (%)                                              20 non-null     float64
# dtypes: float64(66), int64(1)
# memory usage: 10.6 KB

# %%
raw_poverty_df.head()
# Out:
#    Year  Percent Change in People in Poverty Over the Next Two Years(%)  \
# 0  1960                                             -0.012
# 1  1962                                             -0.020
# 2  1964                                             -0.043
# 3  1966                                             -0.019
# 4  1968                                             -0.002
#
#    Unnamed: 2  Percent of people in poverty (%)  Unnamed: 4  Unnamed: 5  \
# 0         NaN                             0.222         NaN         NaN
# 1         NaN                             0.210         NaN         NaN
# 2         NaN                             0.190         NaN         NaN
# 3         NaN                             0.147         NaN         NaN
# 4         NaN                             0.128         NaN         NaN
#
#    Comparison1          Under 18 years (%)  Unnamed: 8  Unnamed: 9  ...  \
# 0        0.210                       0.269         NaN         NaN  ...
# 1        0.190                       0.250         NaN         NaN  ...
# 2        0.147                       0.230         NaN         NaN  ...
# 3        0.128                       0.176         NaN         NaN  ...
# 4        0.126                       0.156         NaN         NaN  ...
#
#            Female householder, no spouse present with children (%)  \
# 0                                              0.563
# 1                                              0.597
# 2                                              0.497
# 3                                              0.471
# 4                                              0.446
#
#    Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Comparison4          White (%)  Unnamed: 26  Comparison5
# 0        0.597              0.178          NaN        0.164
# 1        0.497              0.164          NaN        0.149
# 2        0.471              0.149          NaN        0.113
# 3        0.446              0.113          NaN        0.100
# 4        0.438              0.100          NaN        0.099
#
# [5 rows x 28 columns]

# %%
raw_poverty_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 28 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   Year                                                             30 non-null     int64
#  1   Percent Change in People in Poverty Over the Next Two Years(%)   30 non-null     float64
#  2   Unnamed: 2                                                       0 non-null      float64
#  3   Percent of people in poverty (%)                                 30 non-null     float64
#  4   Unnamed: 4                                                       0 non-null      float64
#  5   Unnamed: 5                                                       0 non-null      float64
#  6   Comparison1                                                      30 non-null     float64
#  7           Under 18 years (%)                                       30 non-null     float64
#  8   Unnamed: 8                                                       0 non-null      float64
#  9   Unnamed: 9                                                       0 non-null      float64
#  10  Comparison2                                                      30 non-null     float64
#  11          Persons not in families/Unrelated individuals (%)        30 non-null     float64
#  12  Unnamed: 12                                                      0 non-null      float64
#  13  Unnamed: 13                                                      0 non-null      float64
#  14  Unnamed: 14                                                      0 non-null      float64
#  15  Unnamed: 15                                                      0 non-null      float64
#  16  Unnamed: 16                                                      0 non-null      float64
#  17  Comparison3                                                      30 non-null     float64
#  18          Female householder, no spouse present with children (%)  30 non-null     float64
#  19  Unnamed: 19                                                      0 non-null      float64
#  20  Unnamed: 20                                                      0 non-null      float64
#  21  Unnamed: 21                                                      0 non-null      float64
#  22  Unnamed: 22                                                      0 non-null      float64
#  23  Unnamed: 23                                                      0 non-null      float64
#  24  Comparison4                                                      30 non-null     float64
#  25          White (%)                                                30 non-null     float64
#  26  Unnamed: 26                                                      0 non-null      float64
#  27  Comparison5                                                      30 non-null     float64
# dtypes: float64(27), int64(1)
# memory usage: 6.7 KB

# %%
raw_voter_df.head()
# Out:
#    Year  U.S Federal Voter Turnout Rate
# 0  1960                            63.8
# 1  1962                            47.7
# 2  1964                            62.8
# 3  1966                            48.7
# 4  1968                            62.5

# %%
raw_voter_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 2 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Year                            31 non-null     int64
#  1   U.S Federal Voter Turnout Rate  31 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 624.0 bytes

# %%
poverty_df = raw_poverty_df.copy()

voter_df = raw_voter_df.copy()

presidential_vs_midterm_df = raw_presidential_vs_midterm_df.copy()

extra_poverty_stats_df = raw_extra_poverty_statistics_df.copy()

welfare_df = raw_welfare_df.copy()

gdp_df = raw_gdp_df.copy()

# %%
poverty_df.columns = poverty_df.columns.str.lower()

voter_df.columns = voter_df.columns.str.lower()

presidential_vs_midterm_df.columns = presidential_vs_midterm_df.columns.str.lower()

extra_poverty_stats_df.columns = extra_poverty_stats_df.columns.str.lower()

welfare_df.columns = welfare_df.columns.str.lower()

gdp_df.columns = gdp_df.columns.str.lower()

# %%
poverty_df.isna().sum()
# Out:
# year                                                                0
# percent change in people in poverty over the next two years(%)      0
# unnamed: 2                                                         30
# percent of people in poverty (%)                                    0
# unnamed: 4                                                         30
# unnamed: 5                                                         30
# comparison1                                                         0
#         under 18 years (%)                                          0
# unnamed: 8                                                         30
# unnamed: 9                                                         30
# comparison2                                                         0
#         persons not in families/unrelated individuals (%)           0
# unnamed: 12                                                        30
# unnamed: 13                                                        30
# unnamed: 14                                                        30
# unnamed: 15                                                        30
# unnamed: 16                                                        30
# comparison3                                                         0
#         female householder, no spouse present with children (%)     0
# unnamed: 19                                                        30
# unnamed: 20                                                        30
# unnamed: 21                                                        30
# unnamed: 22                                                        30
# unnamed: 23                                                        30
# comparison4                                                         0
#         white (%)                                                   0
# unnamed: 26                                                        30
# comparison5                                                         0
# dtype: int64

# %%
voter_df.isna().sum()
# Out:
# year                              0
# u.s federal voter turnout rate    0
# dtype: int64

# %%
presidential_vs_midterm_df.isna().sum()
# Out:
# year                                           0
# united states presidential vep turnout rate    0
# year.1                                         0
# united states vep midterm turnout rate         0
# dtype: int64

# %%
extra_poverty_stats_df.isna().sum()
# Out:
# years                                                   0
#         18 to 64 years (%)                              0
#         65+ years (%)                                   0
#         married couple families without children (%)    0
#         married couple families with children (%)       0
#                                                        ..
#         virginia (%)                                    0
#         washington (%)                                  0
#         west virginia (%)                               0
#         wisconsin (%)                                   0
#         wyoming (%)                                     0
# Length: 67, dtype: int64

# %%
presidential_vs_midterm_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 4 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   year                                         16 non-null     int64
#  1   united states presidential vep turnout rate  16 non-null     object
#  2   year.1                                       16 non-null     int64
#  3   united states vep midterm turnout rate       16 non-null     float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 640.0+ bytes

# %%
poverty_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 28 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   year                                                             30 non-null     int64
#  1   percent change in people in poverty over the next two years(%)   30 non-null     float64
#  2   unnamed: 2                                                       0 non-null      float64
#  3   percent of people in poverty (%)                                 30 non-null     float64
#  4   unnamed: 4                                                       0 non-null      float64
#  5   unnamed: 5                                                       0 non-null      float64
#  6   comparison1                                                      30 non-null     float64
#  7           under 18 years (%)                                       30 non-null     float64
#  8   unnamed: 8                                                       0 non-null      float64
#  9   unnamed: 9                                                       0 non-null      float64
#  10  comparison2                                                      30 non-null     float64
#  11          persons not in families/unrelated individuals (%)        30 non-null     float64
#  12  unnamed: 12                                                      0 non-null      float64
#  13  unnamed: 13                                                      0 non-null      float64
#  14  unnamed: 14                                                      0 non-null      float64
#  15  unnamed: 15                                                      0 non-null      float64
#  16  unnamed: 16                                                      0 non-null      float64
#  17  comparison3                                                      30 non-null     float64
#  18          female householder, no spouse present with children (%)  30 non-null     float64
#  19  unnamed: 19                                                      0 non-null      float64
#  20  unnamed: 20                                                      0 non-null      float64
#  21  unnamed: 21                                                      0 non-null      float64
#  22  unnamed: 22                                                      0 non-null      float64
#  23  unnamed: 23                                                      0 non-null      float64
#  24  comparison4                                                      30 non-null     float64
#  25          white (%)                                                30 non-null     float64
#  26  unnamed: 26                                                      0 non-null      float64
#  27  comparison5                                                      30 non-null     float64
# dtypes: float64(27), int64(1)
# memory usage: 6.7 KB

# %%
sns.boxplot(data=poverty_df['percent change in people in poverty over the next two years(%)'])
# Out:
# <Axes: >

# %%
sns.boxplot(data=voter_df['u.s federal voter turnout rate'])
# Out:
# <Axes: >

# %%
presidential_vs_midterm_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 4 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   year                                         16 non-null     int64
#  1   united states presidential vep turnout rate  16 non-null     object
#  2   year.1                                       16 non-null     int64
#  3   united states vep midterm turnout rate       16 non-null     float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 640.0+ bytes

# %%
voter_list = presidential_vs_midterm_df['united states presidential vep turnout rate']
voter_columns = []

for column in voter_list:
    column = column.replace(",", ".")
    
    voter_columns.append(column)
    
presidential_vs_midterm_df['united states presidential vep turnout rate'] = voter_columns

# %%
presidential_vs_midterm_df['united states presidential vep turnout rate'] = presidential_vs_midterm_df['united states presidential vep turnout rate'].astype(float)

# %%
sns.boxplot(data=presidential_vs_midterm_df['united states presidential vep turnout rate'])
# Out:
# <Axes: >

# %%
sns.boxplot(data=presidential_vs_midterm_df['united states vep midterm turnout rate'])
# Out:
# <Axes: >

# %%
poverty_df.drop(columns=['unnamed: 2'], inplace=True)

# %%
poverty_df.head()
# Out:
#    year  percent change in people in poverty over the next two years(%)  \
# 0  1960                                             -0.012
# 1  1962                                             -0.020
# 2  1964                                             -0.043
# 3  1966                                             -0.019
# 4  1968                                             -0.002
#
#    percent of people in poverty (%)  unnamed: 4  unnamed: 5  comparison1  \
# 0                             0.222         NaN         NaN        0.210
# 1                             0.210         NaN         NaN        0.190
# 2                             0.190         NaN         NaN        0.147
# 3                             0.147         NaN         NaN        0.128
# 4                             0.128         NaN         NaN        0.126
#
#            under 18 years (%)  unnamed: 8  unnamed: 9  comparison2  ...  \
# 0                       0.269         NaN         NaN        0.250  ...
# 1                       0.250         NaN         NaN        0.230  ...
# 2                       0.230         NaN         NaN        0.176  ...
# 3                       0.176         NaN         NaN        0.156  ...
# 4                       0.156         NaN         NaN        0.151  ...
#
#            female householder, no spouse present with children (%)  \
# 0                                              0.563
# 1                                              0.597
# 2                                              0.497
# 3                                              0.471
# 4                                              0.446
#
#    unnamed: 19  unnamed: 20  unnamed: 21  unnamed: 22  unnamed: 23  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    comparison4          white (%)  unnamed: 26  comparison5
# 0        0.597              0.178          NaN        0.164
# 1        0.497              0.164          NaN        0.149
# 2        0.471              0.149          NaN        0.113
# 3        0.446              0.113          NaN        0.100
# 4        0.438              0.100          NaN        0.099
#
# [5 rows x 27 columns]

# %%
presidential_vs_midterm_df
# Out:
#     year  united states presidential vep turnout rate  year.1  \
# 0   1960                                         63.8    1962
# 1   1964                                         62.8    1966
# 2   1968                                         62.5    1970
# 3   1972                                         56.2    1974
# 4   1976                                         54.8    1978
# 5   1980                                         54.2    1982
# 6   1984                                         55.2    1986
# 7   1988                                         52.8    1990
# 8   1992                                         58.1    1994
# 9   1996                                         51.7    1998
# 10  2000                                         54.2    2002
# 11  2004                                         60.1    2006
# 12  2008                                         61.6    2010
# 13  2012                                         58.6    2014
# 14  2016                                         60.1    2018
# 15  2020                                         66.6    2022
#
#     united states vep midterm turnout rate
# 0                                     47.7
# 1                                     48.7
# 2                                     47.3
# 3                                     39.1
# 4                                     39.0
# 5                                     42.0
# 6                                     38.1
# 7                                     38.4
# 8                                     41.1
# 9                                     38.1
# 10                                    39.5
# 11                                    40.4
# 12                                    41.0
# 13                                    36.7
# 14                                    50.0
# 15                                    46.0

# %%
voter_df.head()
# Out:
#    year  u.s federal voter turnout rate
# 0  1960                            63.8
# 1  1962                            47.7
# 2  1964                            62.8
# 3  1966                            48.7
# 4  1968                            62.5

# %%
presidential_vs_midterm_df.columns = presidential_vs_midterm_df.columns.str.lower()

# %%
presidential_vs_midterm_df.head()
# Out:
#    year  united states presidential vep turnout rate  year.1  \
# 0  1960                                         63.8    1962
# 1  1964                                         62.8    1966
# 2  1968                                         62.5    1970
# 3  1972                                         56.2    1974
# 4  1976                                         54.8    1978
#
#    united states vep midterm turnout rate
# 0                                    47.7
# 1                                    48.7
# 2                                    47.3
# 3                                    39.1
# 4                                    39.0

# %%
poverty_df.columns = poverty_df.columns.str.lower()

# %%
poverty_df.head()
# Out:
#    year  percent change in people in poverty over the next two years(%)  \
# 0  1960                                             -0.012
# 1  1962                                             -0.020
# 2  1964                                             -0.043
# 3  1966                                             -0.019
# 4  1968                                             -0.002
#
#    percent of people in poverty (%)  unnamed: 4  unnamed: 5  comparison1  \
# 0                             0.222         NaN         NaN        0.210
# 1                             0.210         NaN         NaN        0.190
# 2                             0.190         NaN         NaN        0.147
# 3                             0.147         NaN         NaN        0.128
# 4                             0.128         NaN         NaN        0.126
#
#            under 18 years (%)  unnamed: 8  unnamed: 9  comparison2  ...  \
# 0                       0.269         NaN         NaN        0.250  ...
# 1                       0.250         NaN         NaN        0.230  ...
# 2                       0.230         NaN         NaN        0.176  ...
# 3                       0.176         NaN         NaN        0.156  ...
# 4                       0.156         NaN         NaN        0.151  ...
#
#            female householder, no spouse present with children (%)  \
# 0                                              0.563
# 1                                              0.597
# 2                                              0.497
# 3                                              0.471
# 4                                              0.446
#
#    unnamed: 19  unnamed: 20  unnamed: 21  unnamed: 22  unnamed: 23  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    comparison4          white (%)  unnamed: 26  comparison5
# 0        0.597              0.178          NaN        0.164
# 1        0.497              0.164          NaN        0.149
# 2        0.471              0.149          NaN        0.113
# 3        0.446              0.113          NaN        0.100
# 4        0.438              0.100          NaN        0.099
#
# [5 rows x 27 columns]

# %%
voter_df.columns = voter_df.columns.str.lower()

voter_df.head()
# Out:
#    year  u.s federal voter turnout rate
# 0  1960                            63.8
# 1  1962                            47.7
# 2  1964                            62.8
# 3  1966                            48.7
# 4  1968                            62.5

# %%
import regex as re

poverty_list = poverty_df.columns.to_list()
poverty_columns = []

for column in poverty_list:
    column = column.replace(" ", "_")
    
    poverty_columns.append(column)
    
voter_list = voter_df.columns.to_list()
voter_columns = []

for column in voter_list:
    column = column.replace(" ", "_")
    
    voter_columns.append(column)
    
presidential_vs_midterm_list = presidential_vs_midterm_df.columns.to_list()
presidential_vs_midterm_columns = []

for column in presidential_vs_midterm_list:
    column = column.replace(" ", "_")
    
    presidential_vs_midterm_columns.append(column)
    
extra_poverty_stats_list = extra_poverty_stats_df.columns.to_list()
extra_poverty_stats_columns = []

for column in extra_poverty_stats_list:
    column = column.replace(" ", "_")
    
    extra_poverty_stats_columns.append(column)
    
welfare_list = welfare_df.columns.to_list()
welfare_columns = []

for column in welfare_list:
    column = column.replace(" ", "_")
    
    welfare_columns.append(column)

gdp_list = gdp_df.columns.to_list()
gdp_columns = []

for column in gdp_list:
    column = column.replace(" ", "_")
    
    gdp_columns.append(column)
    
gdp_df.columns = gdp_columns
welfare_df.columns = welfare_columns
extra_poverty_stats_df.columns = extra_poverty_stats_columns
poverty_df.columns = poverty_columns
voter_df.columns = voter_columns
presidential_vs_midterm_df.columns = presidential_vs_midterm_columns

# %%
gdp_df['real_gdp_per_capita'] = gdp_df['real_gdp_per_capita'].str.replace(",", "").astype(float)

# %%
gdp_df['real_gdp_per_capita']
# Out:
# 0     17776.65
# 1     19125.10
# 2     20575.47
# 3     22783.20
# 4     24055.80
# 5     23959.07
# 6     26146.15
# 7     26172.02
# 8     27459.70
# 9     30114.83
# 10    29882.30
# 11    29270.58
# 12    32759.27
# 13    34490.55
# 14    36728.95
# 15    37127.14
# 16    38133.46
# 17    39744.90
# 18    41420.83
# 19    44342.07
# 20    46790.89
# 21    46915.45
# 22    49676.33
# 23    51504.02
# 24    50332.98
# 25    50936.27
# 26    51766.99
# 27    53664.84
# 28    54992.87
# 29    57214.17
# Name: real_gdp_per_capita, dtype: float64

# %%
gdp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   year                 30 non-null     int64
#  1   real_gdp_per_capita  30 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 608.0 bytes

# %%
welfare_df = welfare_df[['year', '_total_welfare_spending_']]

# %%
welfare_df.head()
# Out:
#    year  _total_welfare_spending_
# 0  1960                     19.27
# 1  1962                     22.04
# 2  1964                     26.04
# 3  1966                     33.01
# 4  1968                     42.43

# %%
poverty_df.head()
# Out:
#    year  percent_change_in_people_in_poverty_over_the_next_two_years(%)  \
# 0  1960                                             -0.012
# 1  1962                                             -0.020
# 2  1964                                             -0.043
# 3  1966                                             -0.019
# 4  1968                                             -0.002
#
#    percent_of_people_in_poverty_(%)  unnamed:_4  unnamed:_5  comparison1  \
# 0                             0.222         NaN         NaN        0.210
# 1                             0.210         NaN         NaN        0.190
# 2                             0.190         NaN         NaN        0.147
# 3                             0.147         NaN         NaN        0.128
# 4                             0.128         NaN         NaN        0.126
#
#    ________under_18_years_(%)  unnamed:_8  unnamed:_9  comparison2  ...  \
# 0                       0.269         NaN         NaN        0.250  ...
# 1                       0.250         NaN         NaN        0.230  ...
# 2                       0.230         NaN         NaN        0.176  ...
# 3                       0.176         NaN         NaN        0.156  ...
# 4                       0.156         NaN         NaN        0.151  ...
#
#    ________female_householder,_no_spouse_present_with_children_(%)  \
# 0                                              0.563
# 1                                              0.597
# 2                                              0.497
# 3                                              0.471
# 4                                              0.446
#
#    unnamed:_19  unnamed:_20  unnamed:_21  unnamed:_22  unnamed:_23  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    comparison4  ________white_(%)  unnamed:_26  comparison5
# 0        0.597              0.178          NaN        0.164
# 1        0.497              0.164          NaN        0.149
# 2        0.471              0.149          NaN        0.113
# 3        0.446              0.113          NaN        0.100
# 4        0.438              0.100          NaN        0.099
#
# [5 rows x 27 columns]

# %%
voter_df.head()
# Out:
#    year  u.s_federal_voter_turnout_rate
# 0  1960                            63.8
# 1  1962                            47.7
# 2  1964                            62.8
# 3  1966                            48.7
# 4  1968                            62.5

# %%
presidential_vs_midterm_df.head()
# Out:
#    year  united_states_presidential_vep_turnout_rate  year.1  \
# 0  1960                                         63.8    1962
# 1  1964                                         62.8    1966
# 2  1968                                         62.5    1970
# 3  1972                                         56.2    1974
# 4  1976                                         54.8    1978
#
#    united_states_vep_midterm_turnout_rate
# 0                                    47.7
# 1                                    48.7
# 2                                    47.3
# 3                                    39.1
# 4                                    39.0

# %%
poverty_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 27 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   year                                                             30 non-null     int64
#  1   percent_change_in_people_in_poverty_over_the_next_two_years(%)   30 non-null     float64
#  2   percent_of_people_in_poverty_(%)                                 30 non-null     float64
#  3   unnamed:_4                                                       0 non-null      float64
#  4   unnamed:_5                                                       0 non-null      float64
#  5   comparison1                                                      30 non-null     float64
#  6   ________under_18_years_(%)                                       30 non-null     float64
#  7   unnamed:_8                                                       0 non-null      float64
#  8   unnamed:_9                                                       0 non-null      float64
#  9   comparison2                                                      30 non-null     float64
#  10  ________persons_not_in_families/unrelated_individuals_(%)        30 non-null     float64
#  11  unnamed:_12                                                      0 non-null      float64
#  12  unnamed:_13                                                      0 non-null      float64
#  13  unnamed:_14                                                      0 non-null      float64
#  14  unnamed:_15                                                      0 non-null      float64
#  15  unnamed:_16                                                      0 non-null      float64
#  16  comparison3                                                      30 non-null     float64
#  17  ________female_householder,_no_spouse_present_with_children_(%)  30 non-null     float64
#  18  unnamed:_19                                                      0 non-null      float64
#  19  unnamed:_20                                                      0 non-null      float64
#  20  unnamed:_21                                                      0 non-null      float64
#  21  unnamed:_22                                                      0 non-null      float64
#  22  unnamed:_23                                                      0 non-null      float64
#  23  comparison4                                                      30 non-null     float64
#  24  ________white_(%)                                                30 non-null     float64
#  25  unnamed:_26                                                      0 non-null      float64
#  26  comparison5                                                      30 non-null     float64
# dtypes: float64(26), int64(1)
# memory usage: 6.5 KB

# %%
voter_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 2 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   year                            31 non-null     int64
#  1   u.s_federal_voter_turnout_rate  31 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 624.0 bytes

# %%
print(presidential_vs_midterm_df['united_states_presidential_vep_turnout_rate'])
# Out:
# 0     63.8
# 1     62.8
# 2     62.5
# 3     56.2
# 4     54.8
# 5     54.2
# 6     55.2
# 7     52.8
# 8     58.1
# 9     51.7
# 10    54.2
# 11    60.1
# 12    61.6
# 13    58.6
# 14    60.1
# 15    66.6
# Name: united_states_presidential_vep_turnout_rate, dtype: float64

# %%
poverty_df['year'] = poverty_df['year'].astype(str)

voter_df['year'] = poverty_df['year'].astype(str)

presidential_vs_midterm_df['year'] = presidential_vs_midterm_df['year'].astype(str)

presidential_vs_midterm_df['year.1'] = presidential_vs_midterm_df['year.1'].astype(str)

# %%
poverty_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 27 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   year                                                             30 non-null     int64
#  1   percent_change_in_people_in_poverty_over_the_next_two_years(%)   30 non-null     float64
#  2   percent_of_people_in_poverty_(%)                                 30 non-null     float64
#  3   unnamed:_4                                                       0 non-null      float64
#  4   unnamed:_5                                                       0 non-null      float64
#  5   comparison1                                                      30 non-null     float64
#  6   ________under_18_years_(%)                                       30 non-null     float64
#  7   unnamed:_8                                                       0 non-null      float64
#  8   unnamed:_9                                                       0 non-null      float64
#  9   comparison2                                                      30 non-null     float64
#  10  ________persons_not_in_families/unrelated_individuals_(%)        30 non-null     float64
#  11  unnamed:_12                                                      0 non-null      float64
#  12  unnamed:_13                                                      0 non-null      float64
#  13  unnamed:_14                                                      0 non-null      float64
#  14  unnamed:_15                                                      0 non-null      float64
#  15  unnamed:_16                                                      0 non-null      float64
#  16  comparison3                                                      30 non-null     float64
#  17  ________female_householder,_no_spouse_present_with_children_(%)  30 non-null     float64
#  18  unnamed:_19                                                      0 non-null      float64
#  19  unnamed:_20                                                      0 non-null      float64
#  20  unnamed:_21                                                      0 non-null      float64
#  21  unnamed:_22                                                      0 non-null      float64
#  22  unnamed:_23                                                      0 non-null      float64
#  23  comparison4                                                      30 non-null     float64
#  24  ________white_(%)                                                30 non-null     float64
#  25  unnamed:_26                                                      0 non-null      float64
#  26  comparison5                                                      30 non-null     float64
# dtypes: float64(26), int64(1)
# memory usage: 6.5 KB

# %%
voter_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 2 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   year                            31 non-null     int64
#  1   u.s_federal_voter_turnout_rate  31 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 624.0 bytes

# %%
presidential_vs_midterm_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 4 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   year                                         16 non-null     int64
#  1   united_states_presidential_vep_turnout_rate  16 non-null     float64
#  2   year.1                                       16 non-null     int64
#  3   united_states_vep_midterm_turnout_rate       16 non-null     float64
# dtypes: float64(2), int64(2)
# memory usage: 640.0 bytes

# %%
poverty_df.isna().sum()
# Out:
# year                                                                0
# percent_change_in_people_in_poverty_over_the_next_two_years(%)      0
# percent_of_people_in_poverty_(%)                                    0
# unnamed:_4                                                         30
# unnamed:_5                                                         30
# comparison1                                                         0
# ________under_18_years_(%)                                          0
# unnamed:_8                                                         30
# unnamed:_9                                                         30
# comparison2                                                         0
# ________persons_not_in_families/unrelated_individuals_(%)           0
# unnamed:_12                                                        30
# unnamed:_13                                                        30
# unnamed:_14                                                        30
# unnamed:_15                                                        30
# unnamed:_16                                                        30
# comparison3                                                         0
# ________female_householder,_no_spouse_present_with_children_(%)     0
# unnamed:_19                                                        30
# unnamed:_20                                                        30
# unnamed:_21                                                        30
# unnamed:_22                                                        30
# unnamed:_23                                                        30
# comparison4                                                         0
# ________white_(%)                                                   0
# unnamed:_26                                                        30
# comparison5                                                         0
# dtype: int64

# %%
voter_df.isna().sum()
# Out:
# year                              0
# u.s_federal_voter_turnout_rate    0
# dtype: int64

# %%
presidential_vs_midterm_df.isna().sum()
# Out:
# year                                           0
# united_states_presidential_vep_turnout_rate    0
# year.1                                         0
# united_states_vep_midterm_turnout_rate         0
# dtype: int64

# %%
voter_df.head()
# Out:
#    year  u.s_federal_voter_turnout_rate
# 0  1960                            63.8
# 1  1962                            47.7
# 2  1964                            62.8
# 3  1966                            48.7
# 4  1968                            62.5

# %%
presidential_vs_midterm_df.head()
# Out:
#    year  united_states_presidential_vep_turnout_rate  year.1  \
# 0  1960                                         63.8    1962
# 1  1964                                         62.8    1966
# 2  1968                                         62.5    1970
# 3  1972                                         56.2    1974
# 4  1976                                         54.8    1978
#
#    united_states_vep_midterm_turnout_rate
# 0                                    47.7
# 1                                    48.7
# 2                                    47.3
# 3                                    39.1
# 4                                    39.0

# %%
voter_df.head()
# Out:
#    year  u.s_federal_voter_turnout_rate
# 0  1960                            63.8
# 1  1962                            47.7
# 2  1964                            62.8
# 3  1966                            48.7
# 4  1968                            62.5

# %%
poverty_df.head()
# Out:
#    year  percent_change_in_people_in_poverty_over_the_next_two_years(%)  \
# 0  1960                                             -0.012
# 1  1962                                             -0.020
# 2  1964                                             -0.043
# 3  1966                                             -0.019
# 4  1968                                             -0.002
#
#    percent_of_people_in_poverty_(%)  unnamed:_4  unnamed:_5  comparison1  \
# 0                             0.222         NaN         NaN        0.210
# 1                             0.210         NaN         NaN        0.190
# 2                             0.190         NaN         NaN        0.147
# 3                             0.147         NaN         NaN        0.128
# 4                             0.128         NaN         NaN        0.126
#
#    ________under_18_years_(%)  unnamed:_8  unnamed:_9  comparison2  ...  \
# 0                       0.269         NaN         NaN        0.250  ...
# 1                       0.250         NaN         NaN        0.230  ...
# 2                       0.230         NaN         NaN        0.176  ...
# 3                       0.176         NaN         NaN        0.156  ...
# 4                       0.156         NaN         NaN        0.151  ...
#
#    ________female_householder,_no_spouse_present_with_children_(%)  \
# 0                                              0.563
# 1                                              0.597
# 2                                              0.497
# 3                                              0.471
# 4                                              0.446
#
#    unnamed:_19  unnamed:_20  unnamed:_21  unnamed:_22  unnamed:_23  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    comparison4  ________white_(%)  unnamed:_26  comparison5
# 0        0.597              0.178          NaN        0.164
# 1        0.497              0.164          NaN        0.149
# 2        0.471              0.149          NaN        0.113
# 3        0.446              0.113          NaN        0.100
# 4        0.438              0.100          NaN        0.099
#
# [5 rows x 27 columns]

# %%
presidential_vs_midterm_df.head()
# Out:
#    year  united_states_presidential_vep_turnout_rate  year.1  \
# 0  1960                                         63.8    1962
# 1  1964                                         62.8    1966
# 2  1968                                         62.5    1970
# 3  1972                                         56.2    1974
# 4  1976                                         54.8    1978
#
#    united_states_vep_midterm_turnout_rate
# 0                                    47.7
# 1                                    48.7
# 2                                    47.3
# 3                                    39.1
# 4                                    39.0

# %%
poverty_df.drop(columns=['unnamed:_4'], inplace=True)

# %%
poverty_df.drop(columns=['unnamed:_5'], inplace=True)

# %%
poverty_df.drop(columns=['unnamed:_8'], inplace=True)

# %%
poverty_df.drop(columns=['comparison1'], inplace=True)

# %%
poverty_df.drop(columns=['unnamed:_9'], inplace=True)

# %%
poverty_df.drop(columns=['comparison2'], inplace=True)

# %%
poverty_df.drop(columns=['unnamed:_12'], inplace=True)

# %%
poverty_df.drop(columns=['unnamed:_13'], inplace=True)

# %%
poverty_df.drop(columns=['unnamed:_14'], inplace=True)

# %%
poverty_df.drop(columns=['unnamed:_15'], inplace=True)

# %%
poverty_df.drop(columns=['unnamed:_16'], inplace=True)

# %%
poverty_df.drop(columns=['comparison3'], inplace=True)

# %%
poverty_df.drop(columns=['unnamed:_19'], inplace=True)

# %%
poverty_df.drop(columns=['unnamed:_20'], inplace=True)

# %%
poverty_df.drop(columns=['unnamed:_21'], inplace=True)

# %%
poverty_df.drop(columns=['unnamed:_22'], inplace=True)

# %%
poverty_df.drop(columns=['unnamed:_23'], inplace=True)

# %%
poverty_df.drop(columns=['comparison4'], inplace=True)

# %%
poverty_df.drop(columns=['unnamed:_26'], inplace=True)

# %%
poverty_df.drop(columns=['comparison5'], inplace=True)

# %%
gdp_df['real_gdp_per_capita']
# Out:
# 0     17776.65
# 1     19125.10
# 2     20575.47
# 3     22783.20
# 4     24055.80
# 5     23959.07
# 6     26146.15
# 7     26172.02
# 8     27459.70
# 9     30114.83
# 10    29882.30
# 11    29270.58
# 12    32759.27
# 13    34490.55
# 14    36728.95
# 15    37127.14
# 16    38133.46
# 17    39744.90
# 18    41420.83
# 19    44342.07
# 20    46790.89
# 21    46915.45
# 22    49676.33
# 23    51504.02
# 24    50332.98
# 25    50936.27
# 26    51766.99
# 27    53664.84
# 28    54992.87
# 29    57214.17
# Name: real_gdp_per_capita, dtype: float64

# %%
gdp_df['gdp_per_capita_change'] = (gdp_df['real_gdp_per_capita'] - gdp_df['real_gdp_per_capita'].shift())

# %%
gdp_df['gdp_per_capita_change'] = gdp_df['gdp_per_capita_change'].shift(-1)

# %%
gdp_df.dropna()
# Out:
#     year  real_gdp_per_capita  gdp_per_capita_change
# 0   1960             17776.65                1348.45
# 1   1962             19125.10                1450.37
# 2   1964             20575.47                2207.73
# 3   1966             22783.20                1272.60
# 4   1968             24055.80                 -96.73
# 5   1970             23959.07                2187.08
# 6   1972             26146.15                  25.87
# 7   1974             26172.02                1287.68
# 8   1976             27459.70                2655.13
# 9   1978             30114.83                -232.53
# 10  1980             29882.30                -611.72
# 11  1982             29270.58                3488.69
# 12  1984             32759.27                1731.28
# 13  1986             34490.55                2238.40
# 14  1988             36728.95                 398.19
# 15  1990             37127.14                1006.32
# 16  1992             38133.46                1611.44
# 17  1994             39744.90                1675.93
# 18  1996             41420.83                2921.24
# 19  1998             44342.07                2448.82
# 20  2000             46790.89                 124.56
# 21  2002             46915.45                2760.88
# 22  2004             49676.33                1827.69
# 23  2006             51504.02               -1171.04
# 24  2008             50332.98                 603.29
# 25  2010             50936.27                 830.72
# 26  2012             51766.99                1897.85
# 27  2014             53664.84                1328.03
# 28  2016             54992.87                2221.30

# %%
welfare_df['_total_welfare_spending_']
# Out:
# 0      19.27
# 1      22.04
# 2      26.04
# 3      33.01
# 4      42.43
# 5      48.70
# 6      80.15
# 7      81.99
# 8     125.47
# 9     133.00
# 10    152.57
# 11    139.76
# 12    146.70
# 13    153.97
# 14    160.73
# 15    166.89
# 16    209.48
# 17    240.56
# 18    248.24
# 19    247.40
# 20    255.67
# 21    286.34
# 22    309.23
# 23    319.53
# 24    348.70
# 25    436.01
# 26    421.44
# 27    413.24
# 28    410.18
# 29    376.45
# Name: _total_welfare_spending_, dtype: float64

# %%
welfare_df['_total_welfare_spending_change'] = (welfare_df['_total_welfare_spending_'] - welfare_df['_total_welfare_spending_'].shift())

# %%
welfare_df['_total_welfare_spending_change'] = welfare_df['_total_welfare_spending_change'].shift(-1)

# %%
welfare_df.dropna()
# Out:
#     year  _total_welfare_spending_  _total_welfare_spending_change
# 0   1960                     19.27                            2.77
# 1   1962                     22.04                            4.00
# 2   1964                     26.04                            6.97
# 3   1966                     33.01                            9.42
# 4   1968                     42.43                            6.27
# 5   1970                     48.70                           31.45
# 6   1972                     80.15                            1.84
# 7   1974                     81.99                           43.48
# 8   1976                    125.47                            7.53
# 9   1978                    133.00                           19.57
# 10  1980                    152.57                          -12.81
# 11  1982                    139.76                            6.94
# 12  1984                    146.70                            7.27
# 13  1986                    153.97                            6.76
# 14  1988                    160.73                            6.16
# 15  1990                    166.89                           42.59
# 16  1992                    209.48                           31.08
# 17  1994                    240.56                            7.68
# 18  1996                    248.24                           -0.84
# 19  1998                    247.40                            8.27
# 20  2000                    255.67                           30.67
# 21  2002                    286.34                           22.89
# 22  2004                    309.23                           10.30
# 23  2006                    319.53                           29.17
# 24  2008                    348.70                           87.31
# 25  2010                    436.01                          -14.57
# 26  2012                    421.44                           -8.20
# 27  2014                    413.24                           -3.06
# 28  2016                    410.18                          -33.73

# %%
poverty_df['under_18_change'] = (poverty_df['________under_18_years_(%)'] - poverty_df['________under_18_years_(%)'].shift())

# %%
poverty_df['under_18_change'] = poverty_df['under_18_change'].shift(-1)

# %%
poverty_df['not_in_families_change'] = (poverty_df['________persons_not_in_families/unrelated_individuals_(%)'] - poverty_df['________persons_not_in_families/unrelated_individuals_(%)'].shift())

# %%
poverty_df['not_in_families_change'] = poverty_df['not_in_families_change'].shift(-1)

# %%
poverty_df['single_mother_change'] = (poverty_df['________female_householder,_no_spouse_present_with_children_(%)'] - poverty_df['________female_householder,_no_spouse_present_with_children_(%)'].shift())

# %%
poverty_df['single_mother_change'] = poverty_df['single_mother_change'].shift(-1)

# %%
poverty_df['white_change'] = (poverty_df['________white_(%)'] - poverty_df['________white_(%)'].shift())

# %%
poverty_df['white_change'] = poverty_df['white_change'].shift(-1)

# %%
poverty_df.head()
# Out:
#    year  percent_change_in_people_in_poverty_over_the_next_two_years(%)  \
# 0  1960                                             -0.012
# 1  1962                                             -0.020
# 2  1964                                             -0.043
# 3  1966                                             -0.019
# 4  1968                                             -0.002
#
#    percent_of_people_in_poverty_(%)  ________under_18_years_(%)  \
# 0                             0.222                       0.269
# 1                             0.210                       0.250
# 2                             0.190                       0.230
# 3                             0.147                       0.176
# 4                             0.128                       0.156
#
#    ________persons_not_in_families/unrelated_individuals_(%)  \
# 0                                              0.167
# 1                                              0.146
# 2                                              0.131
# 3                                              0.105
# 4                                              0.098
#
#    ________female_householder,_no_spouse_present_with_children_(%)  \
# 0                                              0.563
# 1                                              0.597
# 2                                              0.497
# 3                                              0.471
# 4                                              0.446
#
#    ________white_(%)  under_18_change  not_in_families_change  \
# 0              0.178           -0.019                  -0.021
# 1              0.164           -0.020                  -0.015
# 2              0.149           -0.054                  -0.026
# 3              0.113           -0.020                  -0.007
# 4              0.100           -0.005                  -0.013
#
#    single_mother_change  white_change
# 0                 0.034        -0.014
# 1                -0.100        -0.015
# 2                -0.026        -0.036
# 3                -0.025        -0.013
# 4                -0.008        -0.001

# %%
poverty_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 11 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   year                                                             30 non-null     int64
#  1   percent_change_in_people_in_poverty_over_the_next_two_years(%)   30 non-null     float64
#  2   percent_of_people_in_poverty_(%)                                 30 non-null     float64
#  3   ________under_18_years_(%)                                       30 non-null     float64
#  4   ________persons_not_in_families/unrelated_individuals_(%)        30 non-null     float64
#  5   ________female_householder,_no_spouse_present_with_children_(%)  30 non-null     float64
#  6   ________white_(%)                                                30 non-null     float64
#  7   under_18_change                                                  29 non-null     float64
#  8   not_in_families_change                                           29 non-null     float64
#  9   single_mother_change                                             29 non-null     float64
#  10  white_change                                                     29 non-null     float64
# dtypes: float64(10), int64(1)
# memory usage: 2.7 KB

# %%
poverty_df.tail()
# Out:
#     year  percent_change_in_people_in_poverty_over_the_next_two_years(%)  \
# 25  2010                                             -0.001
# 26  2012                                             -0.002
# 27  2014                                             -0.021
# 28  2016                                             -0.009
# 29  2018                                             -0.003
#
#     percent_of_people_in_poverty_(%)  ________under_18_years_(%)  \
# 25                             0.151                       0.220
# 26                             0.150                       0.218
# 27                             0.148                       0.211
# 28                             0.127                       0.180
# 29                             0.118                       0.162
#
#     ________persons_not_in_families/unrelated_individuals_(%)  \
# 25                                              0.111
# 26                                              0.117
# 27                                              0.120
# 28                                              0.105
# 29                                              0.102
#
#     ________female_householder,_no_spouse_present_with_children_(%)  \
# 25                                              0.409
# 26                                              0.409
# 27                                              0.398
# 28                                              0.356
# 29                                              0.338
#
#     ________white_(%)  under_18_change  not_in_families_change  \
# 25              0.130           -0.002                   0.006
# 26              0.127           -0.007                   0.003
# 27              0.127           -0.031                  -0.015
# 28              0.110           -0.018                  -0.003
# 29              0.101              NaN                     NaN
#
#     single_mother_change  white_change
# 25                 0.000        -0.003
# 26                -0.011         0.000
# 27                -0.042        -0.017
# 28                -0.018        -0.009
# 29                   NaN           NaN

# %%
poverty_df.dropna()
# Out:
#     year  percent_change_in_people_in_poverty_over_the_next_two_years(%)  \
# 0   1960                                             -0.012
# 1   1962                                             -0.020
# 2   1964                                             -0.043
# 3   1966                                             -0.019
# 4   1968                                             -0.002
# 5   1970                                             -0.007
# 6   1972                                             -0.007
# 7   1974                                              0.006
# 8   1976                                             -0.004
# 9   1978                                              0.016
# 10  1980                                              0.020
# 11  1982                                             -0.006
# 12  1984                                             -0.008
# 13  1986                                             -0.006
# 14  1988                                              0.005
# 15  1990                                              0.013
# 16  1992                                             -0.003
# 17  1994                                             -0.008
# 18  1996                                             -0.010
# 19  1998                                             -0.014
# 20  2000                                              0.008
# 21  2002                                              0.006
# 22  2004                                             -0.004
# 23  2006                                              0.009
# 24  2008                                              0.019
# 25  2010                                             -0.001
# 26  2012                                             -0.002
# 27  2014                                             -0.021
# 28  2016                                             -0.009
#
#     percent_of_people_in_poverty_(%)  ________under_18_years_(%)  \
# 0                              0.222                       0.269
# 1                              0.210                       0.250
# 2                              0.190                       0.230
# 3                              0.147                       0.176
# 4                              0.128                       0.156
# 5                              0.126                       0.151
# 6                              0.119                       0.151
# 7                              0.112                       0.154
# 8                              0.118                       0.160
# 9                              0.114                       0.159
# 10                             0.130                       0.183
# 11                             0.150                       0.219
# 12                             0.144                       0.215
# 13                             0.136                       0.205
# 14                             0.130                       0.195
# 15                             0.135                       0.206
# 16                             0.148                       0.223
# 17                             0.145                       0.218
# 18                             0.137                       0.205
# 19                             0.127                       0.189
# 20                             0.113                       0.162
# 21                             0.121                       0.167
# 22                             0.127                       0.178
# 23                             0.123                       0.174
# 24                             0.132                       0.190
# 25                             0.151                       0.220
# 26                             0.150                       0.218
# 27                             0.148                       0.211
# 28                             0.127                       0.180
#
#     ________persons_not_in_families/unrelated_individuals_(%)  \
# 0                                               0.167
# 1                                               0.146
# 2                                               0.131
# 3                                               0.105
# 4                                               0.098
# 5                                               0.085
# 6                                               0.070
# 7                                               0.069
# 8                                               0.081
# 9                                               0.067
# 10                                              0.086
# 11                                              0.115
# 12                                              0.106
# 13                                              0.092
# 14                                              0.089
# 15                                              0.085
# 16                                              0.104
# 17                                              0.113
# 18                                              0.095
# 19                                              0.087
# 20                                              0.084
# 21                                              0.094
# 22                                              0.106
# 23                                              0.097
# 24                                              0.106
# 25                                              0.111
# 26                                              0.117
# 27                                              0.120
# 28                                              0.105
#
#     ________female_householder,_no_spouse_present_with_children_(%)  \
# 0                                               0.563
# 1                                               0.597
# 2                                               0.497
# 3                                               0.471
# 4                                               0.446
# 5                                               0.438
# 6                                               0.445
# 7                                               0.437
# 8                                               0.441
# 9                                               0.422
# 10                                              0.429
# 11                                              0.478
# 12                                              0.457
# 13                                              0.460
# 14                                              0.447
# 15                                              0.445
# 16                                              0.462
# 17                                              0.440
# 18                                              0.419
# 19                                              0.387
# 20                                              0.330
# 21                                              0.337
# 22                                              0.359
# 23                                              0.365
# 24                                              0.372
# 25                                              0.409
# 26                                              0.409
# 27                                              0.398
# 28                                              0.356
#
#     ________white_(%)  under_18_change  not_in_families_change  \
# 0               0.178           -0.019                  -0.021
# 1               0.164           -0.020                  -0.015
# 2               0.149           -0.054                  -0.026
# 3               0.113           -0.020                  -0.007
# 4               0.100           -0.005                  -0.013
# 5               0.099            0.000                  -0.015
# 6               0.090            0.003                  -0.001
# 7               0.086            0.006                   0.012
# 8               0.091           -0.001                  -0.014
# 9               0.087            0.024                   0.019
# 10              0.102            0.036                   0.029
# 11              0.120           -0.004                  -0.009
# 12              0.115           -0.010                  -0.014
# 13              0.110           -0.010                  -0.003
# 14              0.101            0.011                  -0.004
# 15              0.107            0.017                   0.019
# 16              0.119           -0.005                   0.009
# 17              0.117           -0.013                  -0.018
# 18              0.112           -0.016                  -0.008
# 19              0.105           -0.027                  -0.003
# 20              0.095            0.005                   0.010
# 21              0.102            0.011                   0.012
# 22              0.108           -0.004                  -0.009
# 23              0.103            0.016                   0.009
# 24              0.112            0.030                   0.005
# 25              0.130           -0.002                   0.006
# 26              0.127           -0.007                   0.003
# 27              0.127           -0.031                  -0.015
# 28              0.110           -0.018                  -0.003
#
#     single_mother_change  white_change
# 0                  0.034        -0.014
# 1                 -0.100        -0.015
# 2                 -0.026        -0.036
# 3                 -0.025        -0.013
# 4                 -0.008        -0.001
# 5                  0.007        -0.009
# 6                 -0.008        -0.004
# 7                  0.004         0.005
# 8                 -0.019        -0.004
# 9                  0.007         0.015
# 10                 0.049         0.018
# 11                -0.021        -0.005
# 12                 0.003        -0.005
# 13                -0.013        -0.009
# 14                -0.002         0.006
# 15                 0.017         0.012
# 16                -0.022        -0.002
# 17                -0.021        -0.005
# 18                -0.032        -0.007
# 19                -0.057        -0.010
# 20                 0.007         0.007
# 21                 0.022         0.006
# 22                 0.006        -0.005
# 23                 0.007         0.009
# 24                 0.037         0.018
# 25                 0.000        -0.003
# 26                -0.011         0.000
# 27                -0.042        -0.017
# 28                -0.018        -0.009

# %%
import numpy as np

sns.set()

import matplotlib.pyplot as plt

# %matplotlib inline

import statsmodels.api as sm

# %%
voting_and_poverty_df = voter_df.merge(poverty_df, how='inner', on='year', left_on=None, right_on=None, left_index=False, right_index=False, sort=False, suffixes=('_x', '_y'), copy=None, indicator=False, validate=None)

# %%
voting_vs_poverty_df = presidential_vs_midterm_df.merge(poverty_df, how='inner', on='year', left_on=None, right_on=None, left_index=False, right_index=False, sort=False, suffixes=('_x', '_y'), copy=None, indicator=False, validate=None)

# %%
voting_vs_poverty_df.head()
# Out:
#    year  united_states_presidential_vep_turnout_rate  year.1  \
# 0  1960                                         63.8    1962
# 1  1964                                         62.8    1966
# 2  1968                                         62.5    1970
# 3  1972                                         56.2    1974
# 4  1976                                         54.8    1978
#
#    united_states_vep_midterm_turnout_rate  \
# 0                                    47.7
# 1                                    48.7
# 2                                    47.3
# 3                                    39.1
# 4                                    39.0
#
#    percent_change_in_people_in_poverty_over_the_next_two_years(%)  \
# 0                                             -0.012
# 1                                             -0.043
# 2                                             -0.002
# 3                                             -0.007
# 4                                             -0.004
#
#    percent_of_people_in_poverty_(%)  ________under_18_years_(%)  \
# 0                             0.222                       0.269
# 1                             0.190                       0.230
# 2                             0.128                       0.156
# 3                             0.119                       0.151
# 4                             0.118                       0.160
#
#    ________persons_not_in_families/unrelated_individuals_(%)  \
# 0                                              0.167
# 1                                              0.131
# 2                                              0.098
# 3                                              0.070
# 4                                              0.081
#
#    ________female_householder,_no_spouse_present_with_children_(%)  \
# 0                                              0.563
# 1                                              0.497
# 2                                              0.446
# 3                                              0.445
# 4                                              0.441
#
#    ________white_(%)  under_18_change  not_in_families_change  \
# 0              0.178           -0.019                  -0.021
# 1              0.149           -0.054                  -0.026
# 2              0.100           -0.005                  -0.013
# 3              0.090            0.003                  -0.001
# 4              0.091           -0.001                  -0.014
#
#    single_mother_change  white_change
# 0                 0.034        -0.014
# 1                -0.026        -0.036
# 2                -0.008        -0.001
# 3                -0.008        -0.004
# 4                -0.019        -0.004

# %%
voting_and_poverty_df.head()
# Out:
#    year  u.s_federal_voter_turnout_rate  \
# 0  1960                            63.8
# 1  1962                            47.7
# 2  1964                            62.8
# 3  1966                            48.7
# 4  1968                            62.5
#
#    percent_change_in_people_in_poverty_over_the_next_two_years(%)  \
# 0                                             -0.012
# 1                                             -0.020
# 2                                             -0.043
# 3                                             -0.019
# 4                                             -0.002
#
#    percent_of_people_in_poverty_(%)  ________under_18_years_(%)  \
# 0                             0.222                       0.269
# 1                             0.210                       0.250
# 2                             0.190                       0.230
# 3                             0.147                       0.176
# 4                             0.128                       0.156
#
#    ________persons_not_in_families/unrelated_individuals_(%)  \
# 0                                              0.167
# 1                                              0.146
# 2                                              0.131
# 3                                              0.105
# 4                                              0.098
#
#    ________female_householder,_no_spouse_present_with_children_(%)  \
# 0                                              0.563
# 1                                              0.597
# 2                                              0.497
# 3                                              0.471
# 4                                              0.446
#
#    ________white_(%)  under_18_change  not_in_families_change  \
# 0              0.178           -0.019                  -0.021
# 1              0.164           -0.020                  -0.015
# 2              0.149           -0.054                  -0.026
# 3              0.113           -0.020                  -0.007
# 4              0.100           -0.005                  -0.013
#
#    single_mother_change  white_change
# 0                 0.034        -0.014
# 1                -0.100        -0.015
# 2                -0.026        -0.036
# 3                -0.025        -0.013
# 4                -0.008        -0.001

# %%
welfare_and_gdp_df = welfare_df.merge(gdp_df, how='inner', on='year', left_on=None, right_on=None, left_index=False, right_index=False, sort=False, suffixes=('_x', '_y'), copy=None, indicator=False, validate=None)

# %%
welfare_and_gdp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30 entries, 0 to 29
# Data columns (total 5 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   year                            30 non-null     int64
#  1   _total_welfare_spending_        30 non-null     float64
#  2   _total_welfare_spending_change  29 non-null     float64
#  3   real_gdp_per_capita             30 non-null     float64
#  4   gdp_per_capita_change           29 non-null     float64
# dtypes: float64(4), int64(1)
# memory usage: 1.4 KB

# %%
voting_and_poverty_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30 entries, 0 to 29
# Data columns (total 12 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   year                                                             30 non-null     int64
#  1   u.s_federal_voter_turnout_rate                                   30 non-null     float64
#  2   percent_change_in_people_in_poverty_over_the_next_two_years(%)   30 non-null     float64
#  3   percent_of_people_in_poverty_(%)                                 30 non-null     float64
#  4   ________under_18_years_(%)                                       30 non-null     float64
#  5   ________persons_not_in_families/unrelated_individuals_(%)        30 non-null     float64
#  6   ________female_householder,_no_spouse_present_with_children_(%)  30 non-null     float64
#  7   ________white_(%)                                                30 non-null     float64
#  8   under_18_change                                                  29 non-null     float64
#  9   not_in_families_change                                           29 non-null     float64
#  10  single_mother_change                                             29 non-null     float64
#  11  white_change                                                     29 non-null     float64
# dtypes: float64(11), int64(1)
# memory usage: 3.0 KB

# %%
voting_and_economics_df = welfare_and_gdp_df.merge(voting_and_poverty_df, how='inner', on='year', left_on=None, right_on=None, left_index=False, right_index=False, sort=False, suffixes=('_x', '_y'), copy=None, indicator=False, validate=None)

# %%
gdp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   year                   30 non-null     int64
#  1   real_gdp_per_capita    30 non-null     float64
#  2   gdp_per_capita_change  29 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 848.0 bytes

# %%
voter_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 2 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   year                            31 non-null     int64
#  1   u.s_federal_voter_turnout_rate  31 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 624.0 bytes

# %%
sns.scatterplot(x=voter_df['u.s_federal_voter_turnout_rate'], y=welfare_df['_total_welfare_spending_change'])
# Out:
# <Axes: xlabel='u.s_federal_voter_turnout_rate', ylabel='_total_welfare_spending_change'>

# %%
sns.scatterplot(x=voter_df['u.s_federal_voter_turnout_rate'], y=gdp_df['gdp_per_capita_change'])
# Out:
# <Axes: xlabel='u.s_federal_voter_turnout_rate', ylabel='gdp_per_capita_change'>

# %%
sns.scatterplot(x=welfare_df['_total_welfare_spending_change'], y=gdp_df['gdp_per_capita_change'])
# Out:
# <Axes: xlabel='_total_welfare_spending_change', ylabel='gdp_per_capita_change'>

# %%
sns.scatterplot(x=welfare_df['_total_welfare_spending_change'], y=poverty_df['percent_change_in_people_in_poverty_over_the_next_two_years(%)'])
# Out:
# <Axes: xlabel='_total_welfare_spending_change', ylabel='percent_change_in_people_in_poverty_over_the_next_two_years(%)'>

# %%
y = poverty_df['percent_change_in_people_in_poverty_over_the_next_two_years(%)']
x1 = welfare_df['_total_welfare_spending_change']

# %%
plt.scatter(x1,y)
plt.xlabel('Change in Welfare Spending', fontsize = 20)
plt.ylabel('Change in Poverty', fontsize = 20)
plt.show()

# %%
print(voting_and_economics_df.corr())
# Out:
#                                                         year  \
# year                                                1.000000
# _total_welfare_spending_                            0.980924
# _total_welfare_spending_change                     -0.022515
# real_gdp_per_capita                                 0.995055
# gdp_per_capita_change                               0.033429
# u.s_federal_voter_turnout_rate                     -0.163106
# percent_change_in_people_in_poverty_over_the_ne...  0.278262
# percent_of_people_in_poverty_(%)                   -0.401559
# ________under_18_years_(%)                         -0.095535
# ________persons_not_in_families/unrelated_indiv... -0.091773
# ________female_householder,_no_spouse_present_w... -0.796897
# ________white_(%)                                  -0.209484
# under_18_change                                     0.152268
# not_in_families_change                              0.313468
# single_mother_change                                0.094658
# white_change                                        0.291665
#
#                                                     _total_welfare_spending_  \
# year                                                                0.980924
# _total_welfare_spending_                                            1.000000
# _total_welfare_spending_change                                     -0.102856
# real_gdp_per_capita                                                 0.973088
# gdp_per_capita_change                                               0.021569
# u.s_federal_voter_turnout_rate                                     -0.130805
# percent_change_in_people_in_poverty_over_the_ne...                  0.240554
# percent_of_people_in_poverty_(%)                                   -0.314174
# ________under_18_years_(%)                                         -0.027832
# ________persons_not_in_families/unrelated_indiv...                 -0.010357
# ________female_householder,_no_spouse_present_w...                 -0.740234
# ________white_(%)                                                  -0.117038
# under_18_change                                                     0.116577
# not_in_families_change                                              0.279694
# single_mother_change                                                0.081309
# white_change                                                        0.243922
#
#                                                     _total_welfare_spending_change  \
# year                                                                     -0.022515
# _total_welfare_spending_                                                 -0.102856
# _total_welfare_spending_change                                            1.000000
# real_gdp_per_capita                                                      -0.002094
# gdp_per_capita_change                                                    -0.178651
# u.s_federal_voter_turnout_rate                                           -0.091130
# percent_change_in_people_in_poverty_over_the_ne...                        0.430637
# percent_of_people_in_poverty_(%)                                         -0.232941
# ________under_18_years_(%)                                               -0.231369
# ________persons_not_in_families/unrelated_indiv...                       -0.247976
# ________female_householder,_no_spouse_present_w...                       -0.153331
# ________white_(%)                                                        -0.251949
# under_18_change                                                           0.444473
# not_in_families_change                                                    0.268639
# single_mother_change                                                      0.328657
# white_change                                                              0.444195
#
#                                                     real_gdp_per_capita  \
# year                                                           0.995055
# _total_welfare_spending_                                       0.973088
# _total_welfare_spending_change                                -0.002094
# real_gdp_per_capita                                            1.000000
# gdp_per_capita_change                                         -0.015161
# u.s_federal_voter_turnout_rate                                -0.149097
# percent_change_in_people_in_poverty_over_the_ne...             0.277719
# percent_of_people_in_poverty_(%)                              -0.411226
# ________under_18_years_(%)                                    -0.128872
# ________persons_not_in_families/unrelated_indiv...            -0.097353
# ________female_householder,_no_spouse_present_w...            -0.820673
# ________white_(%)                                             -0.218997
# under_18_change                                                0.152872
# not_in_families_change                                         0.312739
# single_mother_change                                           0.099850
# white_change                                                   0.292910
#
#                                                     gdp_per_capita_change  \
# year                                                             0.033429
# _total_welfare_spending_                                         0.021569
# _total_welfare_spending_change                                  -0.178651
# real_gdp_per_capita                                             -0.015161
# gdp_per_capita_change                                            1.000000
# u.s_federal_voter_turnout_rate                                  -0.062336
# percent_change_in_people_in_poverty_over_the_ne...              -0.505932
# percent_of_people_in_poverty_(%)                                 0.202053
# ________under_18_years_(%)                                       0.283037
# ________persons_not_in_families/unrelated_indiv...               0.241422
# ________female_householder,_no_spouse_present_w...               0.121593
# ________white_(%)                                                0.229495
# under_18_change                                                 -0.539386
# not_in_families_change                                          -0.472141
# single_mother_change                                            -0.386520
# white_change                                                    -0.532954
#
#                                                     u.s_federal_voter_turnout_rate  \
# year                                                                     -0.163106
# _total_welfare_spending_                                                 -0.130805
# _total_welfare_spending_change                                           -0.091130
# real_gdp_per_capita                                                      -0.149097
# gdp_per_capita_change                                                    -0.062336
# u.s_federal_voter_turnout_rate                                            1.000000
# percent_change_in_people_in_poverty_over_the_ne...                       -0.148139
# percent_of_people_in_poverty_(%)                                          0.253960
# ________under_18_years_(%)                                                0.104026
# ________persons_not_in_families/unrelated_indiv...                        0.314969
# ________female_householder,_no_spouse_present_w...                        0.124254
# ________white_(%)                                                         0.245086
# under_18_change                                                          -0.118253
# not_in_families_change                                                   -0.290790
# single_mother_change                                                      0.190762
# white_change                                                             -0.153556
#
#                                                     percent_change_in_people_in_poverty_over_the_next_two_years(%)  \
# year                                                                                         0.278262
# _total_welfare_spending_                                                                     0.240554
# _total_welfare_spending_change                                                               0.430637
# real_gdp_per_capita                                                                          0.277719
# gdp_per_capita_change                                                                       -0.505932
# u.s_federal_voter_turnout_rate                                                              -0.148139
# percent_change_in_people_in_poverty_over_the_ne...                                           1.000000
# percent_of_people_in_poverty_(%)                                                            -0.581271
# ________under_18_years_(%)                                                                  -0.422091
# ________persons_not_in_families/unrelated_indiv...                                          -0.544878
# ________female_householder,_no_spouse_present_w...                                          -0.435542
# ________white_(%)                                                                           -0.562889
# under_18_change                                                                              0.965773
# not_in_families_change                                                                       0.812115
# single_mother_change                                                                         0.670706
# white_change                                                                                 0.987754
#
#                                                     percent_of_people_in_poverty_(%)  \
# year                                                                       -0.401559
# _total_welfare_spending_                                                   -0.314174
# _total_welfare_spending_change                                             -0.232941
# real_gdp_per_capita                                                        -0.411226
# gdp_per_capita_change                                                       0.202053
# u.s_federal_voter_turnout_rate                                              0.253960
# percent_change_in_people_in_poverty_over_the_ne...                         -0.581271
# percent_of_people_in_poverty_(%)                                            1.000000
# ________under_18_years_(%)                                                  0.877877
# ________persons_not_in_families/unrelated_indiv...                          0.907168
# ________female_householder,_no_spouse_present_w...                          0.770834
# ________white_(%)                                                           0.977188
# under_18_change                                                            -0.553646
# not_in_families_change                                                     -0.528633
# single_mother_change                                                       -0.315974
# white_change                                                               -0.597189
#
#                                                     ________under_18_years_(%)  \
# year                                                                 -0.095535
# _total_welfare_spending_                                             -0.027832
# _total_welfare_spending_change                                       -0.231369
# real_gdp_per_capita                                                  -0.128872
# gdp_per_capita_change                                                 0.283037
# u.s_federal_voter_turnout_rate                                        0.104026
# percent_change_in_people_in_poverty_over_the_ne...                   -0.422091
# percent_of_people_in_poverty_(%)                                      0.877877
# ________under_18_years_(%)                                            1.000000
# ________persons_not_in_families/unrelated_indiv...                    0.829522
# ________female_householder,_no_spouse_present_w...                    0.611857
# ________white_(%)                                                     0.901823
# under_18_change                                                      -0.462422
# not_in_families_change                                               -0.372370
# single_mother_change                                                 -0.281267
# white_change                                                         -0.435453
#
#                                                     ________persons_not_in_families/unrelated_individuals_(%)  \
# year                                                                                        -0.091773
# _total_welfare_spending_                                                                    -0.010357
# _total_welfare_spending_change                                                              -0.247976
# real_gdp_per_capita                                                                         -0.097353
# gdp_per_capita_change                                                                        0.241422
# u.s_federal_voter_turnout_rate                                                               0.314969
# percent_change_in_people_in_poverty_over_the_ne...                                          -0.544878
# percent_of_people_in_poverty_(%)                                                             0.907168
# ________under_18_years_(%)                                                                   0.829522
# ________persons_not_in_families/unrelated_indiv...                                           1.000000
# ________female_householder,_no_spouse_present_w...                                           0.500611
# ________white_(%)                                                                            0.955856
# under_18_change                                                                             -0.552429
# not_in_families_change                                                                      -0.576647
# single_mother_change                                                                        -0.252264
# white_change                                                                                -0.560591
#
#                                                     ________female_householder,_no_spouse_present_with_children_(%)  \
# year                                                                                        -0.796897
# _total_welfare_spending_                                                                    -0.740234
# _total_welfare_spending_change                                                              -0.153331
# real_gdp_per_capita                                                                         -0.820673
# gdp_per_capita_change                                                                        0.121593
# u.s_federal_voter_turnout_rate                                                               0.124254
# percent_change_in_people_in_poverty_over_the_ne...                                          -0.435542
# percent_of_people_in_poverty_(%)                                                             0.770834
# ________under_18_years_(%)                                                                   0.611857
# ________persons_not_in_families/unrelated_indiv...                                           0.500611
# ________female_householder,_no_spouse_present_w...                                           1.000000
# ________white_(%)                                                                            0.631926
# under_18_change                                                                             -0.353347
# not_in_families_change                                                                      -0.449423
# single_mother_change                                                                        -0.352067
# white_change                                                                                -0.452880
#
#                                                     ________white_(%)  \
# year                                                        -0.209484
# _total_welfare_spending_                                    -0.117038
# _total_welfare_spending_change                              -0.251949
# real_gdp_per_capita                                         -0.218997
# gdp_per_capita_change                                        0.229495
# u.s_federal_voter_turnout_rate                               0.245086
# percent_change_in_people_in_poverty_over_the_ne...          -0.562889
# percent_of_people_in_poverty_(%)                             0.977188
# ________under_18_years_(%)                                   0.901823
# ________persons_not_in_families/unrelated_indiv...           0.955856
# ________female_householder,_no_spouse_present_w...           0.631926
# ________white_(%)                                            1.000000
# under_18_change                                             -0.562313
# not_in_families_change                                      -0.506575
# single_mother_change                                        -0.294479
# white_change                                                -0.582648
#
#                                                     under_18_change  \
# year                                                       0.152268
# _total_welfare_spending_                                   0.116577
# _total_welfare_spending_change                             0.444473
# real_gdp_per_capita                                        0.152872
# gdp_per_capita_change                                     -0.539386
# u.s_federal_voter_turnout_rate                            -0.118253
# percent_change_in_people_in_poverty_over_the_ne...         0.965773
# percent_of_people_in_poverty_(%)                          -0.553646
# ________under_18_years_(%)                                -0.462422
# ________persons_not_in_families/unrelated_indiv...        -0.552429
# ________female_householder,_no_spouse_present_w...        -0.353347
# ________white_(%)                                         -0.562313
# under_18_change                                            1.000000
# not_in_families_change                                     0.776435
# single_mother_change                                       0.673403
# white_change                                               0.960297
#
#                                                     not_in_families_change  \
# year                                                              0.313468
# _total_welfare_spending_                                          0.279694
# _total_welfare_spending_change                                    0.268639
# real_gdp_per_capita                                               0.312739
# gdp_per_capita_change                                            -0.472141
# u.s_federal_voter_turnout_rate                                   -0.290790
# percent_change_in_people_in_poverty_over_the_ne...                0.812115
# percent_of_people_in_poverty_(%)                                 -0.528633
# ________under_18_years_(%)                                       -0.372370
# ________persons_not_in_families/unrelated_indiv...               -0.576647
# ________female_householder,_no_spouse_present_w...               -0.449423
# ________white_(%)                                                -0.506575
# under_18_change                                                   0.776435
# not_in_families_change                                            1.000000
# single_mother_change                                              0.482976
# white_change                                                      0.822460
#
#                                                     single_mother_change  \
# year                                                            0.094658
# _total_welfare_spending_                                        0.081309
# _total_welfare_spending_change                                  0.328657
# real_gdp_per_capita                                             0.099850
# gdp_per_capita_change                                          -0.386520
# u.s_federal_voter_turnout_rate                                  0.190762
# percent_change_in_people_in_poverty_over_the_ne...              0.670706
# percent_of_people_in_poverty_(%)                               -0.315974
# ________under_18_years_(%)                                     -0.281267
# ________persons_not_in_families/unrelated_indiv...             -0.252264
# ________female_householder,_no_spouse_present_w...             -0.352067
# ________white_(%)                                              -0.294479
# under_18_change                                                 0.673403
# not_in_families_change                                          0.482976
# single_mother_change                                            1.000000
# white_change                                                    0.615696
#
#                                                     white_change
# year                                                    0.291665
# _total_welfare_spending_                                0.243922
# _total_welfare_spending_change                          0.444195
# real_gdp_per_capita                                     0.292910
# gdp_per_capita_change                                  -0.532954
# u.s_federal_voter_turnout_rate                         -0.153556
# percent_change_in_people_in_poverty_over_the_ne...      0.987754
# percent_of_people_in_poverty_(%)                       -0.597189
# ________under_18_years_(%)                             -0.435453
# ________persons_not_in_families/unrelated_indiv...     -0.560591
# ________female_householder,_no_spouse_present_w...     -0.452880
# ________white_(%)                                      -0.582648
# under_18_change                                         0.960297
# not_in_families_change                                  0.822460
# single_mother_change                                    0.615696
# white_change                                            1.000000

# %%
plt.figure(figsize=(12,8))

ax = sns.heatmap(voting_and_economics_df.corr(), annot=True, cmap='YlGnBu')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[114], line 3
#       1 plt.figure(figsize=(12,8))
# ----> 3 ax = sns.heatmap(voting_and_economics_df.corr(), annot=True, cmap='YlGnBu')
#
# File ~\anaconda3\envs\psycopg\lib\site-packages\seaborn\matrix.py:459, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     457 if square:
#     458     ax.set_aspect("equal")
# --> 459 plotter.plot(ax, cbar_ax, kwargs)
#     460 return ax
#
# File ~\anaconda3\envs\psycopg\lib\site-packages\seaborn\matrix.py:352, in _HeatMapper.plot(self, ax, cax, kws)
#     350 # Annotate the cells with the formatted values
#     351 if self.annot:
# --> 352     self._annotate_heatmap(ax, mesh)
#
# File ~\anaconda3\envs\psycopg\lib\site-packages\seaborn\matrix.py:259, in _HeatMapper._annotate_heatmap(self, ax, mesh)
#     257 if m is not np.ma.masked:
#     258     lum = relative_luminance(color)
# --> 259     text_color = ".15" if lum > .408 else "w"
#     260     annotation = ("{:" + self.fmt + "}").format(val)
#     261     text_kwargs = dict(color=text_color, ha="center", va="center")
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
# Assuming voting_and_economics_df is your DataFrame containing the data

# Normalize the "real_gdp_per_capita" variable
gdp_normalized = (voting_and_economics_df['real_gdp_per_capita'] - voting_and_economics_df['real_gdp_per_capita'].mean()) / voting_and_economics_df['real_gdp_per_capita'].std()

# Normalize the "u.s_federal_voter_turnout_rate" variable
voter_turnout_normalized = (voting_and_economics_df['u.s_federal_voter_turnout_rate'] - voting_and_economics_df['u.s_federal_voter_turnout_rate'].mean()) / voting_and_economics_df['u.s_federal_voter_turnout_rate'].std()

# Normalize the "_total_welfarespending" variable
welfare_normalized = (voting_and_economics_df['_total_welfare_spending_'] - voting_and_economics_df['_total_welfare_spending_'].mean()) / voting_and_economics_df['_total_welfare_spending_'].std()

# %%
normalized_data = pd.DataFrame({'year': voting_and_economics_df['year'],
                               'real_gdp_per_capita': gdp_normalized,
                               'u.s_federal_voter_turnout_rate': voter_turnout_normalized,
                               '_total_welfare_spending_': welfare_normalized})

# %%
sns.lineplot(x='year', y='real_gdp_per_capita', data=normalized_data)
sns.lineplot(x='year', y='u.s_federal_voter_turnout_rate', data=normalized_data)
sns.lineplot(x='year', y='_total_welfare_spending_', data=normalized_data)
plt.show()
